# %% [markdown]
# # **COVID-19 Analysis**

# %% [markdown]
# **Author Name:** Syed Abdul Qadir\
# **Email:** syedabdulqadirgilani7860@gmail.com\
# **Linkedin:** [https://www.linkedin.com/in/syedabdulqadir/](Syed Abdul Qadir Gilani)

# %% [markdown]
# ## Purpose of this analysis:
#
# We will fill this at the end or during the process

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Improt the dataset
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv')

# %% [markdown]
# # 1. Composition

# %%
# Explore the data (Compsotion)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1158 non-null   object
#  1   cases   1158 non-null   int64
#  2   deaths  1158 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 27.3+ KB

# %%
df.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
# max column priniting option 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
# lets see all column names at once
df.columns
# Out:
# Index(['date', 'cases', 'deaths'], dtype='object')

# %%
# let's have a look on dtypes
df.dtypes # we already have seen this in info column as well
# Out:
# date      object
# cases      int64
# deaths     int64
# dtype: object

# %%
# summary Statistics
df.describe().T
# Out:
#          count          mean           std  min         25%         50%  \
# cases   1158.0  4.759746e+07  3.669601e+07  1.0  9732256.75  37757320.5
# deaths  1158.0  6.300682e+05  3.790093e+05  0.0   235646.00    628192.5
#
#                 75%          max
# cases   84917946.75  103910034.0
# deaths   1005825.50    1135343.0

# %%
# how many are the missing value
df.isnull().sum()
# Out:
# date      0
# cases     0
# deaths    0
# dtype: int64

# %%
# box plot
sns.histplot(df, x='cases', kde=True)
# Out:
# <Axes: xlabel='cases', ylabel='Count'>

# %%
sns.boxplot(df, y="cases")
# Out:
# <Axes: ylabel='cases'>

# %%
df.columns
# Out:
# Index(['date', 'cases', 'deaths'], dtype='object')

# %%
sns.boxplot(df, y="deaths",x='cases')
# Out:
# <Axes: xlabel='cases', ylabel='deaths'>

# %%
# it is very hard to plot, therefore, we will use groupby function to make tabulated data output
df['cases'].nunique()
# Out:
# 1138

# %%
len(df)
# Out:
# 1158

# %%
df['deaths'].nunique()
# Out:
# 1108

# %%
df.groupby(['cases']).size().sort_values()
# Out:
# cases
# 39316629     1
# 78942813     1
# 78986396     1
# 79044542     1
# 79096279     1
# 79145866     1
# 79162481     1
# 79169256     1
# 79232308     1
# 79266324     1
# 79314028     1
# 79352221     1
# 79396596     1
# 79407518     1
# 79413908     1
# 79462956     1
# 79511352     1
# 79550748     1
# 79966408     1
# 79920966     1
# 79895338     1
# 79853102     1
# 79845604     1
# 79833549     1
# 78835013     1
# 79799812     1
# 79714979     1
# 79689310     1
# 79643175     1
# 79635322     1
# 79623203     1
# 79586734     1
# 79762066     1
# 78825927     1
# 78800705     1
# 78714719     1
# 76359918     1
# 76236151     1
# 75923171     1
# 75610929     1
# 75285900     1
# 74989495     1
# 76418395     1
# 74327523     1
# 73981352     1
# 73425577     1
# 72895313     1
# 72210867     1
# 71699954     1
# 70667795     1
# 74223465     1
# 80004185     1
# 76766514     1
# 77187359     1
# 78641313     1
# 78556769     1
# 78433652     1
# 78377993     1
# ...

# %%
df.head()
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
df.groupby(['cases']).size().sort_values(ascending=False)
# Out:
# cases
# 12           5
# 5            4
# 15           4
# 1            3
# 11           3
# 30           3
# 25           3
# 60           2
# 13           2
# 79162481     1
# 79511352     1
# 79462956     1
# 79413908     1
# 79407518     1
# 79396596     1
# 79352221     1
# 79314028     1
# 79145866     1
# 79266324     1
# 79044542     1
# 79232308     1
# 79586734     1
# 79096279     1
# 79169256     1
# 79550748     1
# 79714979     1
# 79623203     1
# 79853102     1
# 80048015     1
# 80036620     1
# 80004185     1
# 79966408     1
# 79920966     1
# 79895338     1
# 79845604     1
# 79635322     1
# 79833549     1
# 79799812     1
# 79762066     1
# 78942813     1
# 79689310     1
# 79643175     1
# 78986396     1
# 78714719     1
# 78835013     1
# 75610929     1
# 76961010     1
# 76766514     1
# 76418395     1
# 76359918     1
# 76236151     1
# 75923171     1
# 75285900     1
# 78825927     1
# 74989495     1
# 74327523     1
# 74223465     1
# 73981352     1
# ...

# %%
df.groupby(['cases']).size().sort_values(ascending=False)
# Out:
# cases
# 12           5
# 5            4
# 15           4
# 1            3
# 11           3
# 30           3
# 25           3
# 60           2
# 13           2
# 79162481     1
# 79511352     1
# 79462956     1
# 79413908     1
# 79407518     1
# 79396596     1
# 79352221     1
# 79314028     1
# 79145866     1
# 79266324     1
# 79044542     1
# 79232308     1
# 79586734     1
# 79096279     1
# 79169256     1
# 79550748     1
# 79714979     1
# 79623203     1
# 79853102     1
# 80048015     1
# 80036620     1
# 80004185     1
# 79966408     1
# 79920966     1
# 79895338     1
# 79845604     1
# 79635322     1
# 79833549     1
# 79799812     1
# 79762066     1
# 78942813     1
# 79689310     1
# 79643175     1
# 78986396     1
# 78714719     1
# 78835013     1
# 75610929     1
# 76961010     1
# 76766514     1
# 76418395     1
# 76359918     1
# 76236151     1
# 75923171     1
# 75285900     1
# 78825927     1
# 74989495     1
# 74327523     1
# 74223465     1
# 73981352     1
# ...

# %%
df.describe().T
# Out:
#          count          mean           std  min         25%         50%  \
# cases   1158.0  4.759746e+07  3.669601e+07  1.0  9732256.75  37757320.5
# deaths  1158.0  6.300682e+05  3.790093e+05  0.0   235646.00    628192.5
#
#                 75%          max
# cases   84917946.75  103910034.0
# deaths   1005825.50    1135343.0

# %%
# How much cases were reported in 2020
df['cases'].sum()
# Out:
# 55117854172

# %%
# How much deaths were reported in 2020
df['deaths'].sum()
# Out:
# 729618999

# %%
# Cases change over time
cases_over_time = df.groupby(['date'])['cases'].sum().reset_index()
cases_over_time.head()
# Out:
#          date  cases
# 0  2020-01-21      1
# 1  2020-01-22      1
# 2  2020-01-23      1
# 3  2020-01-24      2
# 4  2020-01-25      3
